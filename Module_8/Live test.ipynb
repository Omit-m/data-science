# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(11)

fig, axes = plt.subplots()
axes.plot(x, x+2, color='blue', label='x+2') 
axes.plot(x, x+3, color='orange',label='x+3')
axes.legend(loc=4)
plt.show()
